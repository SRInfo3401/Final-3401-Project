# %%
import numpy as np
import csv
import pandas as pd

df = pd.read_hdf('fixed-dd-comment-profile-clean-with-c3po.hdf')
df.head(10)
# Out:
#    comment_id        comment_date  \
# 0           1 2010-04-03 02:42:00
# 1           2 2010-03-20 16:21:00
# 2           3 2010-02-24 01:29:00
# 3           4 2010-02-21 02:46:00
# 4           5 2010-02-10 02:26:00
# 5           6 2010-02-02 00:59:00
# 6           7 2010-01-30 03:03:00
# 7           8 2010-01-24 19:27:00
# 8          11 2010-01-16 22:05:00
# 9          12 2010-01-14 22:57:00
#
#                                          comment_msg  deceased_id date_death  \
# 0   miss you and love you tell  we miss him and w...            3 2010-01-07
# 1  there is not a day that goes by that i don't t...            3 2010-01-07
# 2   we miss you soo much we wish you didnt have t...            3 2010-01-07
# 3                looove you uncle forever and always            3 2010-01-07
# 4                       missss youuuu aloooooooooot             3 2010-01-07
# 5  love you and miss you i wish you were here to ...            3 2010-01-07
# 6                                  i love you heart             3 2010-01-07
# 7  everything would be so much better if you were...            3 2010-01-07
# 8  missssssssss you beyond words uncle  i think a...            3 2010-01-07
# 9  rip  we  miss you alot and we love you with al...            3 2010-01-07
#
#    comment_postmortem_ind  LIWC_1ST_PLURAL  LIWC_1ST_SINGULAR  \
# 0                       1         0.074074           0.074074
# 1                       1         0.024096           0.084337
# 2                       1         0.208333           0.000000
# 3                       1         0.000000           0.000000
# 4                       1         0.000000           0.000000
# 5                       1         0.032258           0.096774
# 6                       1         0.000000           0.250000
# 7                       1         0.000000           0.055556
# 8                       1         0.000000           0.052632
# 9                       1         0.133333           0.022222
#
#    LIWC_3RD_PLURAL  LIWC_3RD_SINGULAR    ...      Empath_giving  \
# 0         0.000000           0.074074    ...                0.0
# 1         0.012048           0.012048    ...                0.0
# 2         0.000000           0.000000    ...                0.0
# 3         0.000000           0.000000    ...                0.0
# 4         0.000000           0.000000    ...                0.0
# 5         0.000000           0.000000    ...                0.0
# 6         0.000000           0.000000    ...                0.0
# 7         0.000000           0.000000    ...                0.0
# 8         0.000000           0.000000    ...                0.0
# 9         0.000000           0.000000    ...                0.0
#
#    Empath_contentment  Empath_writing  Empath_rural  Empath_positive_emotion  \
# 0                 0.0             0.0           0.0                 0.071429
# 1                 0.0             0.0           0.0                 0.037500
# 2                 0.0             0.0           0.0                 0.041667
# 3                 0.0             0.0           0.0                 0.000000
# 4                 0.0             0.0           0.0                 0.000000
# 5                 0.0             0.0           0.0                 0.030303
# 6                 0.0             0.0           0.0                 0.250000
# 7                 0.0             0.0           0.0                 0.050000
# 8                 0.0             0.0           0.0                 0.000000
# 9                 0.0             0.0           0.0                 0.045455
#
#    Empath_musical  Vader_compound  Vader_neg  Vader_neu  Vader_pos
# 0             0.0          0.8020      0.095      0.655      0.250
# 1             0.0          0.9263      0.098      0.687      0.215
# 2             0.0          0.3067      0.065      0.777      0.157
# 3             0.0          0.0000      0.000      1.000      0.000
# 4             0.0          0.0000      0.000      1.000      0.000
# 5             0.0          0.9246      0.041      0.622      0.337
# 6             0.0          0.6369      0.000      0.323      0.677
# 7             0.0          0.3774      0.077      0.770      0.153
# 8             0.0          0.6124      0.000      0.800      0.200
# 9             0.0          0.7096      0.068      0.782      0.150
#
# [10 rows x 288 columns]

# %%
csv_df = pd.read_csv('parsedHDF.csv')
csv_df.head(10)
# Out:
#    Unnamed: 0  comment_id         comment_date  \
# 0           0           1  2010-04-03 02:42:00
# 1           1           2  2010-03-20 16:21:00
# 2           2           3  2010-02-24 01:29:00
# 3           3           4  2010-02-21 02:46:00
# 4           4           5  2010-02-10 02:26:00
# 5           5           6  2010-02-02 00:59:00
# 6           6           7  2010-01-30 03:03:00
# 7           7           8  2010-01-24 19:27:00
# 8           8          11  2010-01-16 22:05:00
# 9           9          12  2010-01-14 22:57:00
#
#                                          comment_msg  deceased_id  \
# 0   miss you and love you tell  we miss him and w...            3
# 1  there is not a day that goes by that i don't t...            3
# 2   we miss you soo much we wish you didnt have t...            3
# 3                looove you uncle forever and always            3
# 4                       missss youuuu aloooooooooot             3
# 5  love you and miss you i wish you were here to ...            3
# 6                                  i love you heart             3
# 7  everything would be so much better if you were...            3
# 8  missssssssss you beyond words uncle  i think a...            3
# 9  rip  we  miss you alot and we love you with al...            3
#
#             date_death  comment_postmortem_ind  LIWC_1ST_PLURAL  \
# 0  2010-01-07 00:00:00                       1         0.074074
# 1  2010-01-07 00:00:00                       1         0.024096
# 2  2010-01-07 00:00:00                       1         0.208333
# 3  2010-01-07 00:00:00                       1         0.000000
# 4  2010-01-07 00:00:00                       1         0.000000
# 5  2010-01-07 00:00:00                       1         0.032258
# 6  2010-01-07 00:00:00                       1         0.000000
# 7  2010-01-07 00:00:00                       1         0.000000
# 8  2010-01-07 00:00:00                       1         0.000000
# 9  2010-01-07 00:00:00                       1         0.133333
#
#    LIWC_1ST_SINGULAR  LIWC_3RD_PLURAL    ...      Empath_giving  \
# 0           0.074074         0.000000    ...                0.0
# 1           0.084337         0.012048    ...                0.0
# 2           0.000000         0.000000    ...                0.0
# 3           0.000000         0.000000    ...                0.0
# 4           0.000000         0.000000    ...                0.0
# 5           0.096774         0.000000    ...                0.0
# 6           0.250000         0.000000    ...                0.0
# 7           0.055556         0.000000    ...                0.0
# 8           0.052632         0.000000    ...                0.0
# 9           0.022222         0.000000    ...                0.0
#
#    Empath_contentment  Empath_writing  Empath_rural  Empath_positive_emotion  \
# 0                 0.0             0.0           0.0                 0.071429
# 1                 0.0             0.0           0.0                 0.037500
# 2                 0.0             0.0           0.0                 0.041667
# 3                 0.0             0.0           0.0                 0.000000
# 4                 0.0             0.0           0.0                 0.000000
# 5                 0.0             0.0           0.0                 0.030303
# 6                 0.0             0.0           0.0                 0.250000
# 7                 0.0             0.0           0.0                 0.050000
# 8                 0.0             0.0           0.0                 0.000000
# 9                 0.0             0.0           0.0                 0.045455
#
#    Empath_musical  Vader_compound  Vader_neg  Vader_neu  Vader_pos
# 0             0.0          0.8020      0.095      0.655      0.250
# 1             0.0          0.9263      0.098      0.687      0.215
# 2             0.0          0.3067      0.065      0.777      0.157
# 3             0.0          0.0000      0.000      1.000      0.000
# 4             0.0          0.0000      0.000      1.000      0.000
# 5             0.0          0.9246      0.041      0.622      0.337
# 6             0.0          0.6369      0.000      0.323      0.677
# 7             0.0          0.3774      0.077      0.770      0.153
# 8             0.0          0.6124      0.000      0.800      0.200
# 9             0.0          0.7096      0.068      0.782      0.150
#
# [10 rows x 289 columns]

# %%
#Check length before clean
len(df)
# Out:
# 1056720

# %%
df.dtypes
# Out:
# comment_id                            int64
# comment_date                 datetime64[ns]
# comment_msg                          object
# deceased_id                           int64
# date_death                   datetime64[ns]
# comment_postmortem_ind                int64
# LIWC_1ST_PLURAL                     float64
# LIWC_1ST_SINGULAR                   float64
# LIWC_3RD_PLURAL                     float64
# LIWC_3RD_SINGULAR                   float64
# LIWC_ABBREVIATIONS                  float64
# LIWC_ACHIEVEMENT                    float64
# LIWC_ADVERBS                        float64
# LIWC_AFFECTIVE_PROCESSES            float64
# LIWC_ALLPCT                         float64
# LIWC_ANGER                          float64
# LIWC_ANXIETY                        float64
# LIWC_APOSTRO                        float64
# LIWC_ARTICLES                       float64
# LIWC_ASSENT                         float64
# LIWC_AUXILIARY_VERBS                float64
# LIWC_BIOLOGICAL_PROCESSES           float64
# LIWC_BODY                           float64
# LIWC_CAUSATION                      float64
# LIWC_CERTAINTY                      float64
# LIWC_COGNITIVE_PROCESSES            float64
# LIWC_COLON                          float64
# LIWC_COMMA                          float64
# LIWC_COMMON_VERBS                   float64
# LIWC_CONJUNCTIONS                   float64
#                                   ...
# Empath_pain                         float64
# Empath_beauty                       float64
# Empath_timidity                     float64
# Empath_philosophy                   float64
# Empath_negotiate                    float64
# Empath_negative_emotion             float64
# Empath_cleaning                     float64
# Empath_messaging                    float64
# Empath_competing                    float64
# Empath_law                          float64
# Empath_friends                      float64
# Empath_payment                      float64
# Empath_achievement                  float64
# Empath_alcohol                      float64
# Empath_liquid                       float64
# Empath_feminine                     float64
# Empath_weapon                       float64
# Empath_children                     float64
# Empath_monster                      float64
# Empath_ocean                        float64
# Empath_giving                       float64
# Empath_contentment                  float64
# Empath_writing                      float64
# Empath_rural                        float64
# Empath_positive_emotion             float64
# Empath_musical                      float64
# Vader_compound                      float64
# Vader_neg                           float64
# Vader_neu                           float64
# Vader_pos                           float64
# Length: 288, dtype: object

# %%
#Way more enpath columns than anticipated.
#Parsed instead
df.drop('Empath_musical', axis=1, inplace=True)
df.drop('Empath_rural', axis=1, inplace=True) 
df.drop('Empath_writing', axis=1, inplace=True)
df.drop('Empath_contentment', axis=1, inplace=True)
df.drop('Empath_giving', axis=1, inplace=True)
df.head(3)
# Out:
#    comment_id        comment_date  \
# 0           1 2010-04-03 02:42:00
# 1           2 2010-03-20 16:21:00
# 2           3 2010-02-24 01:29:00
#
#                                          comment_msg  deceased_id date_death  \
# 0   miss you and love you tell  we miss him and w...            3 2010-01-07
# 1  there is not a day that goes by that i don't t...            3 2010-01-07
# 2   we miss you soo much we wish you didnt have t...            3 2010-01-07
#
#    comment_postmortem_ind  LIWC_1ST_PLURAL  LIWC_1ST_SINGULAR  \
# 0                       1         0.074074           0.074074
# 1                       1         0.024096           0.084337
# 2                       1         0.208333           0.000000
#
#    LIWC_3RD_PLURAL  LIWC_3RD_SINGULAR    ...      Empath_feminine  \
# 0         0.000000           0.074074    ...                  0.0
# 1         0.012048           0.012048    ...                  0.0
# 2         0.000000           0.000000    ...                  0.0
#
#    Empath_weapon  Empath_children  Empath_monster  Empath_ocean  \
# 0            0.0            0.000             0.0           0.0
# 1            0.0            0.025             0.0           0.0
# 2            0.0            0.000             0.0           0.0
#
#    Empath_positive_emotion  Vader_compound  Vader_neg  Vader_neu  Vader_pos
# 0                 0.071429          0.8020      0.095      0.655      0.250
# 1                 0.037500          0.9263      0.098      0.687      0.215
# 2                 0.041667          0.3067      0.065      0.777      0.157
#
# [3 rows x 283 columns]
